# %% [markdown]
# <a href="https://colab.research.google.com/github/bhaskarpondugala/NASSCOM_AI_FDP/blob/main/Day7_FN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %% [markdown]
# ## Google Colab is available in VS Code!
# ![logo.webp](data:image/webp;base64,...)
#
# Try the new [Google Colab extension](https://marketplace.visualstudio.com/items?itemName=Google.colab) for Visual Studio Code. You can get up and running in just a few clicks:
#
# *  In VS Code, open the ***Extensions*** view and search for 'Google Colab' to install.
# *  Open the kernel selector by creating or opening any `.ipynb` notebook file in your local workspace and either running a cell or clicking the ***Select Kernel*** button in the top right.
# *  Click ***Colab*** and then select your desired runtime, sign in with your Google account, and you're all set!
#
# See more details in our [announcement blog here](https://developers.googleblog.com/google-colab-is-coming-to-vs-code).

# %% [markdown]
# ## Access popular AI models via Google-Colab-AI Without an API Key
# All users have access to most popular LLMs via the `google-colab-ai` Python library, and paid users have access to a wider selection of models. For more details, refer to the [getting started with google colab ai](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb).

# %%
from google.colab import ai
response = ai.generate_text("What is the capital of France?")

# %% [markdown]
# ## Explore the Gemini API
# The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#
# **How to get started?**
# *  Go to [Google AI Studio](https://aistudio.google.com/) and log in with your Google account.
# *  [Create an API key](https://aistudio.google.com/app/apikey).
# * Use a quickstart for [Python](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb), or call the REST API using [curl](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb).
#
# **Discover Gemini's advanced capabilities**
# *  Play with Gemini [multimodal outputs](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Image-out.ipynb), mixing text and images in an iterative way.
# *  Discover the [multimodal Live API](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_LiveAPI.ipynb ) (demo [here](https://aistudio.google.com/live)).
# *  Learn how to [analyze images and detect items in your pictures](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Spatial_understanding.ipynb") using Gemini (bonus, there's a [3D version](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Spatial_understanding_3d.ipynb) as well!).
# *  Unlock the power of [Gemini thinking model](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_thinking.ipynb), capable of solving complex task with its inner thoughts.
#
# **Explore complex use cases**
# *  Use [Gemini grounding capabilities](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Search_grounding_for_research_report.ipynb) to create a report on a company based on what the model can find on internet.
# *  Extract [invoices and form data from PDF](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Pdf_structured_outputs_on_invoices_and_forms.ipynb) in a structured way.
# *  Create [illustrations based on a whole book](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Book_illustration.ipynb) using Gemini large context window and Imagen.
#
# To learn more, check out the [Gemini cookbook](https://github.com/google-gemini/cookbook) or visit the [Gemini API documentation](https://ai.google.dev/docs/).

# %% [markdown]
# Colab now has AI features powered by [Gemini](https://gemini.google.com). The video below provides information on how to use these features, whether you're new to Python, or a seasoned veteran.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=V7RXyqFUR98" target="_blank">
#   <img alt='Thumbnail for a video showing 3 AI-powered Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) or [Colab Features You May Have Missed](https://www.youtube.com/watch?v=rNgswRZ2C1Y) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.
#
# For example, if you find yourself waiting for **pandas** code to finish running and want to go faster, you can switch to a GPU Runtime and use libraries like [RAPIDS cuDF](https://rapids.ai/cudf-pandas) that provide zero-code-change acceleration.

# %% [markdown]
# To learn more about accelerating pandas on Colab, see the [10 minute guide](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_colab_demo.ipynb) or
#  [US stock market data analysis demo](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_stocks_demo.ipynb).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb).

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colab](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning
#
# <div>
#
# These are a few of the notebooks related to Machine Learning, including Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Intro to RAPIDS cuDF to accelerate pandas](https://nvda.ws/rapids-cudf)
# - [Getting Started with cuML's accelerator mode](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cuml_sklearn_colab_demo.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [Train a CNN to classify handwritten digits on the MNIST dataset using Flax NNX API](https://colab.research.google.com/github/google/flax/blob/main/docs_nnx/mnist_tutorial.ipynb)
# - [Train a Vision Transformer (ViT) for image classification with JAX](https://colab.research.google.com/github/jax-ml/jax-ai-stack/blob/main/docs/source/JAX_Vision_transformer.ipynb)
# - [Text classification with a transformer language model using JAX](https://colab.research.google.com/github/jax-ml/jax-ai-stack/blob/main/docs/source/JAX_transformer_text_classification.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [Train a miniGPT language model with JAX AI Stack](https://docs.jaxstack.ai/en/latest/JAX_for_LLM_pretraining.html)
# - [LoRA/QLoRA finetuning for LLM using Tunix](https://github.com/google/tunix/blob/main/examples/qlora_gemma.ipynb)
# - [Parameter-efficient fine-tuning of Gemma with LoRA and QLoRA](https://keras.io/examples/keras_recipes/parameter_efficient_finetuning_of_gemma_with_lora_and_qlora/)
# - [Loading Hugging Face Transformers Checkpoints](https://keras.io/keras_hub/guides/hugging_face_keras_integration/)
# - [8-bit Integer Quantization in Keras](https://keras.io/guides/int8_quantization_in_keras/)
# - [Float8 training and inference with a simple Transformer model](https://keras.io/examples/keras_recipes/float8_training_and_inference_with_transformer/)
# - [Pretraining a Transformer from scratch with KerasHub](https://keras.io/keras_hub/guides/transformer_pretraining/)
# - [Simple MNIST convnet](https://keras.io/examples/vision/mnist_convnet/)
# - [Image classification from scratch using Keras 3](https://keras.io/examples/vision/image_classification_from_scratch/)
# - [Image Classification with KerasHub](https://keras.io/keras_hub/guides/classification_with_keras_hub/)

# %%
import os
import numpy as np
import pandas as pd


def build_turbine(csv_path="turbine_energy.csv", seed=152, verbose=False):
    """Wind-turbine daily energy yield — a nonlinear regression with a skewed target,
    correlated features, an outlier-prone signal and a feature that needs transforming.
    Ideal for residual diagnostics, transforms, regularisation and tree ensembles.

    Features:
      wind_speed_ms        average wind speed (m/s)
      wind_std_ms          gustiness (std of wind speed)
      air_density_kgm3     air density (kg/m^3)
      turbulence_intensity fraction (0-1)
      blade_pitch_deg      blade pitch angle (deg)
      rotor_rpm            rotor speed (rpm)
      ambient_temp_c       ambient temperature (deg C)
      turbine_age_years    age of the turbine (years)
    Target:
      energy_kwh           daily energy produced (kWh) — right-skewed
    """
    rng = np.random.default_rng(seed)
    N = 1600
    wind = np.clip(rng.weibull(2.0, N) * 7.0, 0.5, 26)          # Weibull -> right-skew
    wind_std = np.clip(0.12 * wind + rng.normal(0, 0.3, N), 0.05, None)
    density = np.clip(rng.normal(1.225, 0.04, N), 1.10, 1.35)
    turb = np.clip(rng.normal(0.14, 0.05, N), 0.02, 0.40)
    pitch = np.clip(rng.normal(4, 6, N), -2, 25)
    rpm = np.clip(8 + 0.9 * wind + rng.normal(0, 1.5, N), 4, 30)  # correlated with wind
    temp = rng.normal(15, 9, N).round(1)
    age = rng.uniform(0, 20, N)

    # power ~ density * v^3 up to rated, then flattens; losses from pitch, turbulence, age
    cube = np.minimum(wind, 13) ** 3                              # cubic then saturates near rated
    rated_extra = np.maximum(wind - 13, 0) * 120
    energy = (density * (3.1 * cube + rated_extra)
              - 35 * np.abs(pitch - 2)
              - 1800 * turb
              - 22 * age
              + rng.normal(0, 280, N))
    energy = np.clip(energy, 0, None)
    # a few sensor-glitch outliers
    g = rng.choice(N, 18, replace=False)
    energy[g] = energy[g] * rng.uniform(1.6, 2.4, len(g))

    df = pd.DataFrame({
        "wind_speed_ms": wind.round(2), "wind_std_ms": wind_std.round(2),
        "air_density_kgm3": density.round(3), "turbulence_intensity": turb.round(3),
        "blade_pitch_deg": pitch.round(1), "rotor_rpm": rpm.round(1),
        "ambient_temp_c": temp, "turbine_age_years": age.round(1),
        "energy_kwh": energy.round(1),
    })
    df.to_csv(csv_path, index=False)
    if verbose:
        from scipy.stats import skew
        print("turbine:", df.shape)
        print("energy range:", df.energy_kwh.min(), "-", df.energy_kwh.max())
        print("target skew:", round(skew(df.energy_kwh), 2))
        print("corr(wind, energy):", round(df.wind_speed_ms.corr(df.energy_kwh), 3))
        print("corr(wind, rpm):", round(df.wind_speed_ms.corr(df.rotor_rpm), 3))
    return df

if not os.path.exists('turbine_energy.csv'):
    build_turbine(); print('Generated dataset file.')
else:
    print('Found the provided dataset file.')


import pandas as pd, numpy as np, matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
df = pd.read_csv('turbine_energy.csv')
TARGET = 'energy_kwh'
features = [c for c in df.columns if c != TARGET]
X = df[features].values; y = df[TARGET].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
print('shape:', df.shape, '| features:', len(features))
df.head(3)
# Out:
# Generated dataset file.
# shape: (1600, 9) | features: 8
#    wind_speed_ms  wind_std_ms  air_density_kgm3  turbulence_intensity  \
# 0           4.95         0.81             1.238                 0.185
# 1           6.83         0.84             1.265                 0.169
# 2           1.44         0.05             1.225                 0.114
#
#    blade_pitch_deg  rotor_rpm  ambient_temp_c  turbine_age_years  energy_kwh
# 0             -1.2       13.1             2.4                2.7         0.0
# 1             -2.0       15.3            12.1                5.9       527.2
# 2             -2.0        7.3            26.1                1.2         0.0

# %%
# 🔹 1A. LINEAR BASELINE + RESIDUAL PLOT
# -----------------------------------------------------------
lin = LinearRegression().fit(X_train, y_train)
pred = lin.predict(X_test)
resid = y_test - pred
print(f'baseline RMSE: {mean_squared_error(y_test, pred) ** 0.5:.1f} kWh | R2: {r2_score(y_test, pred):.3f}')
fig, ax = plt.subplots(1, 2, figsize=(11, 3.6))
ax[0].scatter(pred, resid, s=10, alpha=0.3, color='#2D6A9F')
ax[0].axhline(0, color='#C0392B', ls='--'); ax[0].set_xlabel('predicted'); ax[0].set_ylabel('residual')
ax[0].set_title('Residuals vs predicted')
ax[1].hist(resid, bins=40, color='#3AAFA9'); ax[1].set_title('Residual distribution')
plt.tight_layout(); plt.show()
print('Look for curvature / a fan shape (heteroscedasticity) and skewed residuals.')
# Out:
# baseline RMSE: 1032.5 kWh | R2: 0.727
# Look for curvature / a fan shape (heteroscedasticity) and skewed residuals.

# %%
# 🔹 1B. Q-Q PLOT — ARE THE ERRORS NORMAL?
# -----------------------------------------------------------
from scipy import stats
fig, ax = plt.subplots(figsize=(5, 4))
stats.probplot(resid, dist='norm', plot=ax)
ax.set_title('Q-Q plot of residuals'); plt.tight_layout(); plt.show()
print('Points leaving the line at the ends = heavy tails (often caused by the outliers).')
# Out:
# Points leaving the line at the ends = heavy tails (often caused by the outliers).

# %%
# skew of the target

# %%
from scipy.stats import skew

# Calculate and print the skewness of the target variable
target_skew = skew(df[TARGET])
print(f'Skewness of the target variable ({TARGET}): {target_skew:.2f}')
# Out:
# Skewness of the target variable (energy_kwh): 2.21

# %%
import seaborn as sns

fig, ax = plt.subplots(figsize=(6, 4))
sns.histplot(df[TARGET], kde=True, ax=ax, color='#2D6A9F')
ax.set_title(f'Distribution of {TARGET}')
ax.set_xlabel(TARGET)
ax.set_ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# Given the strong right skewness observed (2.21), applying a transformation to the target variable (`energy_kwh`) can often improve the performance of linear models, as they typically assume normally distributed residuals. A common and effective transformation for right-skewed data, especially when it includes zero values, is the `log1p` (logarithmic + 1) transformation.

# %%
y_train_transformed = np.log1p(y_train)
y_test_transformed = np.log1p(y_test)

# Recalculate skewness for the transformed target variable
transformed_target_skew = skew(np.concatenate([y_train_transformed, y_test_transformed]))
print(f'Skewness of the transformed target variable ({TARGET}): {transformed_target_skew:.2f}')
# Out:
# Skewness of the transformed target variable (energy_kwh): -0.15

# %%
fig, ax = plt.subplots(figsize=(6, 4))
sns.histplot(np.concatenate([y_train_transformed, y_test_transformed]), kde=True, ax=ax, color='#2D6A9F')
ax.set_title(f'Distribution of Transformed {TARGET}')
ax.set_xlabel(f'log1p({TARGET})')
ax.set_ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# As you can see, the `np.log1p` transformation has significantly reduced the skewness of the `energy_kwh` variable, making its distribution much more symmetrical and closer to a normal distribution. This transformation can help improve the linearity and homoscedasticity assumptions of linear regression models.

# %%
# 2A. PHYSICS-INFORMED FEATURE TRANSFORM (power ~ wind^3)
# -----------------------------------------------------------
# The residual curve comes from the cubic wind->power law. Add wind^2 and wind^3.
wi = features.index('wind_speed_ms')
def add_wind_poly(M):
    w = M[:, wi:wi + 1]
    return np.hstack([M, w ** 2, w ** 3])
Xtr_aug, Xte_aug = add_wind_poly(X_train), add_wind_poly(X_test)
lin_aug = LinearRegression().fit(Xtr_aug, y_train)
pred_aug = lin_aug.predict(Xte_aug)
print(f'baseline           R2: {r2_score(y_test, pred):.3f}')
print(f'+ wind^2, wind^3   R2: {r2_score(y_test, pred_aug):.3f}')
print('Matching the feature to the physics straightens the relationship.')
# Out:
# baseline           R2: 0.727
# + wind^2, wind^3   R2: 0.935
# Matching the feature to the physics straightens the relationship.

# %%
ind_test = X_test[:, wi]
# residuals vs wind for baseline and augmented

# %%
fig, ax = plt.subplots(1, 2, figsize=(11, 3.6), sharex=True, sharey=True)

# Baseline residuals vs wind speed
ax[0].scatter(ind_test, resid, s=10, alpha=0.3, color='#2D6A9F')
ax[0].axhline(0, color='#C0392B', ls='--')
ax[0].set_xlabel('Wind Speed (m/s)'); ax[0].set_ylabel('Residual')
ax[0].set_title('Baseline: Residuals vs Wind Speed')

# Augmented model residuals vs wind speed
resid_aug = y_test - pred_aug
ax[1].scatter(ind_test, resid_aug, s=10, alpha=0.3, color='#3AAFA9')
ax[1].axhline(0, color='#C0392B', ls='--')
ax[1].set_xlabel('Wind Speed (m/s)'); ax[1].set_ylabel('Residual')
ax[1].set_title('Augmented: Residuals vs Wind Speed')

plt.tight_layout()
plt.show()

print('Observe how the polynomial features of wind speed have flattened the residual pattern against wind speed, indicating a better model fit for this feature.')
# Out:
# Observe how the polynomial features of wind speed have flattened the residual pattern against wind speed, indicating a better model fit for this feature.

# %%
# is the curve gone? ...   (comment)

# %%
# 3A. COMPARE THE THREE (scaled, degree-2 features)
# -----------------------------------------------------------
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import make_pipeline
def score_model(model):
    m = make_pipeline(StandardScaler(), PolynomialFeatures(2, include_bias=False), model)
    m.fit(X_train, y_train)
    return r2_score(y_test, m.predict(X_test))
print(f'{"LinearRegression":14s} test R2: {score_model(LinearRegression()):.3f}')
for name, mdl in [('Ridge', Ridge(alpha=10.0)), ('Lasso', Lasso(alpha=1.0, max_iter=10000)),
                  ('ElasticNet', ElasticNet(alpha=1.0, l1_ratio=0.5, max_iter=10000))]:
    print(f'{name:14s} test R2: {score_model(mdl):.3f}')
# Out:
# LinearRegression test R2: 0.908
# Ridge          test R2: 0.908
# Lasso          test R2: 0.909
# ElasticNet     test R2: 0.863

# %% [markdown]
# ### 3B. ElasticNet `l1_ratio` Sweep
#
# Let's evaluate the `ElasticNet` model performance by sweeping through different values of the `l1_ratio` parameter. The `l1_ratio` controls the balance between L1 (Lasso) and L2 (Ridge) regularization.

# %%
print('--- ElasticNet l1_ratio sweep ---')
l1_ratios = np.linspace(0.0, 1.0, 11) # Sweep from pure L2 (0.0) to pure L1 (1.0)

for l1 in l1_ratios:
    # Set alpha to a reasonable value, e.g., 1.0, for consistency with previous ElasticNet
    mdl = ElasticNet(alpha=1.0, l1_ratio=l1, max_iter=10000)
    r2 = score_model(mdl)
    print(f'ElasticNet (l1_ratio={l1:.1f}) R2: {r2:.3f}')
# Out:
# --- ElasticNet l1_ratio sweep ---
# ElasticNet (l1_ratio=0.0) R2: 0.826
# ElasticNet (l1_ratio=0.1) R2: 0.833
# ElasticNet (l1_ratio=0.2) R2: 0.840
# ElasticNet (l1_ratio=0.3) R2: 0.848
# ElasticNet (l1_ratio=0.4) R2: 0.855
# ElasticNet (l1_ratio=0.5) R2: 0.863
# ElasticNet (l1_ratio=0.6) R2: 0.870
# ElasticNet (l1_ratio=0.7) R2: 0.878
# ElasticNet (l1_ratio=0.8) R2: 0.887
# ElasticNet (l1_ratio=0.9) R2: 0.898
# ElasticNet (l1_ratio=1.0) R2: 0.909
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.325e+08, tolerance: 4.809e+05 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(

# %%
# best mix + meaning of the extremes: ...   (comment)

# %%
# ORDINARY vs ROBUST (Huber) REGRESSION
# -----------------------------------------------------------
from sklearn.linear_model import HuberRegressor
ols = make_pipeline(StandardScaler(), LinearRegression()).fit(X_train, y_train)
hub = make_pipeline(StandardScaler(), HuberRegressor(max_iter=2000)).fit(X_train, y_train)
print('OLS    test R2:', round(r2_score(y_test, ols.predict(X_test)), 3))
print('Huber  test R2:', round(r2_score(y_test, hub.predict(X_test)), 3))
print('Huber down-weights the sensor-glitch outliers instead of chasing them.')
# Out:
# OLS    test R2: 0.727
# Huber  test R2: 0.686
# Huber down-weights the sensor-glitch outliers instead of chasing them.

# %%
residuals_mean = np.mean(resid)
residuals_std = np.std(resid)

# Define 3-sigma bounds
upper_bound = residuals_mean + 3 * residuals_std
lower_bound = residuals_mean - 3 * residuals_std

# Count residuals beyond 3 sigma
outliers_3sigma = np.sum((resid > upper_bound) | (resid < lower_bound))
total_residuals = len(resid)

print(f'Number of residuals beyond 3 sigma: {outliers_3sigma} ({(outliers_3sigma / total_residuals * 100):.2f}%)')
# Out:
# Number of residuals beyond 3 sigma: 4 (1.00%)

# %%
# 5A. DECISION TREE vs RANDOM FOREST vs GRADIENT BOOSTING
# -----------------------------------------------------------
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
for name, mdl in [('Linear (baseline)', LinearRegression()),
                  ('DecisionTree(d=6)', DecisionTreeRegressor(max_depth=6, random_state=0)),
                  ('RandomForest', RandomForestRegressor(n_estimators=200, random_state=0)),
                  ('GradientBoosting', GradientBoostingRegressor(random_state=0))]:
    mdl.fit(X_train, y_train)
    print(f'{name:20s} test R2: {r2_score(y_test, mdl.predict(X_test)):.3f}')
# Out:
# Linear (baseline)    test R2: 0.727
# DecisionTree(d=6)    test R2: 0.885
# RandomForest         test R2: 0.933
# GradientBoosting     test R2: 0.938

# %%
# 5B. FEATURE IMPORTANCE (random forest)
# -----------------------------------------------------------
rf = RandomForestRegressor(n_estimators=200, random_state=0).fit(X_train, y_train)
imp = pd.Series(rf.feature_importances_, index=features).sort_values()
fig, ax = plt.subplots(figsize=(7, 4))
imp.plot(kind='barh', color='#2D6A9F', ax=ax); ax.set_title('Random-forest feature importance')
plt.tight_layout(); plt.show()

# %% [markdown]
# ### 6. Grid Search for Gradient Boosting
#
# Let's perform a grid search to optimize the hyperparameters of the `GradientBoostingRegressor`. We will tune `n_estimators` (number of boosting stages), `learning_rate` (contribution of each tree), and `max_depth` (maximum depth of the individual regression estimators).

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor

# Define the parameter grid for GradientBoostingRegressor
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 4, 5]
}

# Initialize the GridSearchCV object
grid_search = GridSearchCV(
    estimator=GradientBoostingRegressor(random_state=0),
    param_grid=param_grid,
    cv=3,  # 3-fold cross-validation
    scoring='r2',
    n_jobs=-1, # Use all available cores
    verbose=1
)

print("Starting Grid Search...")
# Out:
# Starting Grid Search...

# %%
# Perform the grid search on the training data
grid_search.fit(X_train, y_train)

# Print the best parameters and the best R2 score found during cross-validation
print(f"\nBest parameters: {grid_search.best_params_}")
print(f"Best cross-validation R2: {grid_search.best_score_:.3f}")

# Evaluate the best estimator on the test set
best_gbr = grid_search.best_estimator_
test_r2 = r2_score(y_test, best_gbr.predict(X_test))
print(f"Test R2 with best parameters: {test_r2:.3f}")
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
#
# Best parameters: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}
# Best cross-validation R2: 0.964
# Test R2 with best parameters: 0.939

# %% [markdown]
# The grid search has identified the optimal hyperparameters for the `GradientBoostingRegressor` and provided the corresponding R2 score on the test set, indicating the model's performance with these optimized settings.

# %% [markdown]
# ### Predicted vs. Actual Values for Best Gradient Boosting Model
#
# This plot shows how well the optimized Gradient Boosting model's predictions align with the actual energy consumption values. A perfect model would have all points lying exactly on the diagonal line.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get predictions from the best GradientBoostingRegressor
y_pred_gbr = best_gbr.predict(X_test)

fig, ax = plt.subplots(figsize=(7, 5))

# Scatter plot of actual vs. predicted values
ax.scatter(y_test, y_pred_gbr, alpha=0.5, color='#2D6A9F')

# Add a line for perfect predictions
min_val = min(y_test.min(), y_pred_gbr.min())
max_val = max(y_test.max(), y_pred_gbr.max())
ax.plot([min_val, max_val], [min_val, max_val], color='#C0392B', linestyle='--', linewidth=2)

ax.set_xlabel('Actual energy_kwh')
ax.set_ylabel('Predicted energy_kwh')
ax.set_title('Actual vs. Predicted Values (GradientBoostingRegressor)')
ax.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mean Absolute Error (MAE) for the Best Gradient Boosting Model
#
# The Mean Absolute Error (MAE) provides a measure of the average magnitude of the errors in a set of predictions, without considering their direction. It is the average over the test sample of the absolute differences between prediction and actual observation where all individual differences have equal weight.

# %%
from sklearn.metrics import mean_absolute_error

# Get predictions from the best GradientBoostingRegressor
y_pred_gbr = best_gbr.predict(X_test)

# Calculate Mean Absolute Error
mae = mean_absolute_error(y_test, y_pred_gbr)

print(f"Mean Absolute Error for the Best GradientBoostingRegressor: {mae:.2f} kWh")
# Out:
# Mean Absolute Error for the Best GradientBoostingRegressor: 192.00 kWh

# %% [markdown]
# ### Model Comparison: Complexity vs. Performance

# %%
import pandas as pd

model_comparison_data = [
    {
        'Model': 'Linear Regression (Baseline)',
        'Complexity / Features': 'Original features',
        'Test R2 Score': 0.727
    },
    {
        'Model': 'Linear Regression (Physics-Informed)',
        'Complexity / Features': 'Original + wind^2, wind^3',
        'Test R2 Score': 0.935
    },
    {
        'Model': 'Linear Regression (with PolyFeatures(2))',
        'Complexity / Features': 'Original + PolynomialFeatures(2) + StandardScaler',
        'Test R2 Score': 0.908
    },
    {
        'Model': 'Ridge Regression (with PolyFeatures(2))',
        'Complexity / Features': 'Original + PolynomialFeatures(2) + StandardScaler, L2 regularization',
        'Test R2 Score': 0.908
    },
    {
        'Model': 'Lasso Regression (with PolyFeatures(2))',
        'Complexity / Features': 'Original + PolynomialFeatures(2) + StandardScaler, L1 regularization',
        'Test R2 Score': 0.909
    },
    {
        'Model': 'ElasticNet Regression (with PolyFeatures(2))',
        'Complexity / Features': 'Original + PolynomialFeatures(2) + StandardScaler, L1/L2 regularization (l1_ratio=1.0)',
        'Test R2 Score': 0.909
    },
    {
        'Model': 'Huber Regression',
        'Complexity / Features': 'Original features + StandardScaler, robust to outliers',
        'Test R2 Score': 0.686
    },
    {
        'Model': 'Decision Tree Regressor (max_depth=6)',
        'Complexity / Features': 'Original features, tree-based',
        'Test R2 Score': 0.885
    },
    {
        'Model': 'Random Forest Regressor',
        'Complexity / Features': 'Original features, ensemble tree-based',
        'Test R2 Score': 0.933
    },
    {
        'Model': 'Gradient Boosting Regressor (Default)',
        'Complexity / Features': 'Original features, ensemble boosting tree-based',
        'Test R2 Score': 0.938
    },
    {
        'Model': 'Gradient Boosting Regressor (Tuned)',
        'Complexity / Features': 'Original features, ensemble boosting tree-based (n_estimators=200, learning_rate=0.05, max_depth=3)',
        'Test R2 Score': 0.939
    }
]

model_comparison_df = pd.DataFrame(model_comparison_data)
display(model_comparison_df)
# Out:
#                                            Model  \
# 0                   Linear Regression (Baseline)
# 1           Linear Regression (Physics-Informed)
# 2       Linear Regression (with PolyFeatures(2))
# 3        Ridge Regression (with PolyFeatures(2))
# 4        Lasso Regression (with PolyFeatures(2))
# 5   ElasticNet Regression (with PolyFeatures(2))
# 6                               Huber Regression
# 7          Decision Tree Regressor (max_depth=6)
# 8                        Random Forest Regressor
# 9          Gradient Boosting Regressor (Default)
# 10           Gradient Boosting Regressor (Tuned)
#
#                                 Complexity / Features  Test R2 Score
# 0                                   Original features          0.727
# 1                           Original + wind^2, wind^3          0.935
# 2   Original + PolynomialFeatures(2) + StandardScaler          0.908
# 3   Original + PolynomialFeatures(2) + StandardSca...          0.908
# ...

# %%
import tkinter as tk
from tkinter import messagebox

def validate_login():
    # Retrieve data from input fields
    username = username_entry.get()
    password = password_entry.get()

    # Simple hardcoded check (replace with database logic later)
    if username == "admin" and password == "secret123":
        messagebox.showinfo("Login Successful", "Welcome to the application!")
        root.destroy()  # Closes the login window upon success
    else:
        messagebox.showerror("Login Failed", "Invalid username or password.")

# 1. Initialize the main window
root = tk.Tk()
root.title("Secure Login Form")
root.geometry("350x250")
root.resizable(False, False)  # Freezes window size

# Add some vertical spacing at the top
top_spacer = tk.Label(root, text="")
top_spacer.pack(pady=5)

# 2. Username Layout
username_label = tk.Label(root, text="Username:", font=("Arial", 10, "bold"))
username_label.pack(pady=2)

username_entry = tk.Tk().children.get(None) # Placeholders for packaging layout
username_entry = tk.Entry(root, width=30, font=("Arial", 10))
username_entry.pack(pady=5)

# 3. Password Layout
password_label = tk.Label(root, text="Password:", font=("Arial", 10, "bold"))
password_label.pack(pady=2)

# show="*" hides the user's typed password text
password_entry = tk.Entry(root, width=30, font=("Arial", 10), show="*")
password_entry.pack(pady=5)

# 4. Action Button
login_button = tk.Button(root, text="Login", width=15, bg="#4CAF50", fg="white", font=("Arial", 10, "bold"), command=validate_login)
login_button.pack(pady=20)

# 5. Execute the GUI loop
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipykernel_760/3568711825.py in <cell line: 0>()
#      15
#      16 # 1. Initialize the main window
# ---> 17 root = tk.Tk()
#      18 root.title("Secure Login Form")
#      19 root.geometry("350x250")
#
# /usr/lib/python3.12/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2347                 baseName = baseName + ext
#    2348         interactive = False
# -> 2349         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2350         if _debug:
#    2351             self.tk.settrace(_print_command)
#
# TclError: no display name and no $DISPLAY environment variable

# %% [markdown]
# ### Alternatives for Web-Based Interfaces in Colab:
#
# 1.  **`ipywidgets`**: For creating interactive controls (like sliders, text boxes, buttons) directly within your Jupyter/Colab notebook. It's excellent for adding interactive elements to your analysis and visualizations.
#
# 2.  **`Dash` by Plotly**: A powerful framework for building analytical web applications. It allows you to create interactive dashboards entirely in Python, which can be run and accessed from Colab (often requires port forwarding or Ngrok for external access).
#
# 3.  **`Streamlit`**: Simplifies the process of turning data scripts into shareable web apps. It's very user-friendly and focuses on quick development of data-centric applications.
#
# 4.  **`Gradio`**: Primarily used for building web interfaces around machine learning models, making it easy to demo models directly in a browser. It's quick to set up and ideal for showcasing ML prototypes.

# %% [markdown]
# #### Example using `ipywidgets`:
#
# `ipywidgets` is great for adding interactive controls directly into your notebook. Here's a simple example:

# %%
import ipywidgets as widgets
from IPython.display import display

# Create a text input widget
text_input = widgets.Text(
    value='Hello Bhaskar!',
    description='Your Name:',
    disabled=False
)

# Create a button widget
button = widgets.Button(
    description='Click Me!',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me to greet!',
    icon='check' # (FontAwesome names available)
)

# Create an output widget to display results
output = widgets.Output()

def on_button_click(b):
    with output:
        print(f'Hello, {text_input.value}!')

# Attach the click event handler to the button
button.on_click(on_button_click)

# Display the widgets
display(text_input, button, output)
# Out:
# Text(value='Hello Bhaskar!', description='Your Name:')
# Button(description='Click Me!', icon='check', style=ButtonStyle(), tooltip='Click me to greet!')
# Output()

# %% [markdown]
# ### Interactive Dashboard with `ipywidgets` for Energy Prediction
#
# This dashboard allows you to interactively adjust the input features of the wind turbine and observe the predicted daily energy output (`energy_kwh`) from our optimized Gradient Boosting model.

# %%
import ipywidgets as widgets
from IPython.display import display
import numpy as np
import pandas as pd # Import pandas for DataFrame creation within the predict function

# Ensure the best_gbr model is available (it should be from previous cells)
# best_gbr is already available in the kernel from cell 7789366b

# Define the features that the model expects (from earlier context)
features = [
    'wind_speed_ms', 'wind_std_ms', 'air_density_kgm3', 'turbulence_intensity',
    'blade_pitch_deg', 'rotor_rpm', 'ambient_temp_c', 'turbine_age_years'
]

# Create widgets for each feature with sensible ranges
widget_wind_speed_ms = widgets.FloatSlider(min=0.5, max=26.0, step=0.1, value=7.0, description='Wind Speed (m/s)')
widget_wind_std_ms = widgets.FloatSlider(min=0.05, max=5.0, step=0.01, value=0.8, description='Wind Std (m/s)')
widget_air_density_kgm3 = widgets.FloatSlider(min=1.1, max=1.35, step=0.001, value=1.225, description='Air Density (kg/m^3)')
widget_turbulence_intensity = widgets.FloatSlider(min=0.02, max=0.4, step=0.01, value=0.14, description='Turbulence Intensity')
widget_blade_pitch_deg = widgets.FloatSlider(min=-2.0, max=25.0, step=0.1, value=4.0, description='Blade Pitch (deg)')
widget_rotor_rpm = widgets.FloatSlider(min=4.0, max=30.0, step=0.1, value=15.0, description='Rotor RPM')
widget_ambient_temp_c = widgets.FloatSlider(min=-10.0, max=40.0, step=0.1, value=15.0, description='Ambient Temp (C)')
widget_turbine_age_years = widgets.FloatSlider(min=0.0, max=20.0, step=0.1, value=10.0, description='Turbine Age (years)')

# Output widget to display the prediction
prediction_output = widgets.Output()

def make_prediction(
    wind_speed_ms,
    wind_std_ms,
    air_density_kgm3,
    turbulence_intensity,
    blade_pitch_deg,
    rotor_rpm,
    ambient_temp_c,
    turbine_age_years
):
    # Create a DataFrame from the input values (model expects 2D array or DataFrame)
    input_data = pd.DataFrame([[
        wind_speed_ms,
        wind_std_ms,
        air_density_kgm3,
        turbulence_intensity,
        blade_pitch_deg,
        rotor_rpm,
        ambient_temp_c,
        turbine_age_years
    ]], columns=features)

    predicted_energy = best_gbr.predict(input_data)[0]

    with prediction_output:
        prediction_output.clear_output()
        print(f'Predicted Daily Energy: {predicted_energy:.2f} kWh')

# Arrange widgets in a VBox
input_widgets = widgets.VBox([
    widget_wind_speed_ms,
    widget_wind_std_ms,
    widget_air_density_kgm3,
    widget_turbulence_intensity,
    widget_blade_pitch_deg,
    widget_rotor_rpm,
    widget_ambient_temp_c,
    widget_turbine_age_years
])

# Use interactive_output to connect widgets to the prediction function
interactive_dashboard = widgets.interactive_output(
    make_prediction,
    {
        'wind_speed_ms': widget_wind_speed_ms,
        'wind_std_ms': widget_wind_std_ms,
        'air_density_kgm3': widget_air_density_kgm3,
        'turbulence_intensity': widget_turbulence_intensity,
        'blade_pitch_deg': widget_blade_pitch_deg,
        'rotor_rpm': widget_rotor_rpm,
        'ambient_temp_c': widget_ambient_temp_c,
        'turbine_age_years': widget_turbine_age_years
    }
)

# Display the input widgets and the output area
display(input_widgets, prediction_output)
# Out:
# ...
# Output()

# %%
# === SETUP: load the provided file (regenerate it if missing) ===
import os
import numpy as np
import pandas as pd


def build_welds(csv_path="weld_inspection.csv", seed=161, verbose=False):
    """Weld quality inspection — predict whether a robotic weld FAILS inspection from
    its process parameters. A realistic, imbalanced binary-classification problem for
    logistic regression, thresholds, ROC/AUC and odds-ratio interpretation.

    Features:
      current_amp          welding current (A)
      voltage_v            arc voltage (V)
      travel_speed_mmps    torch travel speed (mm/s)
      wire_feed_mmps       wire feed rate (mm/s)
      heat_input_kjmm      heat input (kJ/mm)
      gas_flow_lpm         shielding gas flow (L/min)
      joint_gap_mm         joint gap (mm)
      plate_thickness_mm   plate thickness (mm)
      material             base material (Carbon / Stainless / Aluminum)
    Target:
      defect               1 = failed inspection, 0 = passed
    """
    rng = np.random.default_rng(seed)
    N = 2600
    current = rng.normal(190, 30, N).clip(90, 300)
    voltage = (18 + 0.03 * current + rng.normal(0, 1.2, N)).clip(14, 32)
    travel = rng.normal(8, 2.2, N).clip(3, 16)
    wire = (current * 0.03 + rng.normal(0, 0.6, N)).clip(2, 12)
    heat = (voltage * current / (travel * 1000)).clip(0.2, 4.0)     # kJ/mm
    gas = rng.normal(16, 3, N).clip(6, 28)
    gap = rng.gamma(2.0, 0.35, N).clip(0, 4).round(2)               # right-skewed
    thick = rng.choice([3, 5, 6, 8, 10, 12, 16], N).astype(float)
    material = rng.choice(["Carbon", "Stainless", "Aluminum"], N, p=[0.55, 0.30, 0.15])
    mat_risk = np.select([material == "Carbon", material == "Stainless", material == "Aluminum"],
                         [0.0, 0.3, 0.8])                            # Aluminum harder to weld

    # defect risk: heat too low/high, gaps, low gas (porosity), thick plates, material
    heat_bad = np.abs(heat - 1.3)
    z = (-3.2
         + 1.6 * heat_bad
         + 1.1 * gap
         + 0.05 * (16 - gas)
         + 0.04 * (thick - 8)
         + 0.012 * (travel - 8) ** 2
         + mat_risk)
    p = 1 / (1 + np.exp(-z))
    defect = (rng.random(N) < p).astype(int)

    df = pd.DataFrame({
        "current_amp": current.round(1), "voltage_v": voltage.round(2),
        "travel_speed_mmps": travel.round(2), "wire_feed_mmps": wire.round(2),
        "heat_input_kjmm": heat.round(3), "gas_flow_lpm": gas.round(1),
        "joint_gap_mm": gap, "plate_thickness_mm": thick,
        "material": material, "defect": defect,
    })
    df.to_csv(csv_path, index=False)
    if verbose:
        print("welds:", df.shape)
        print("defect rate:", round(df.defect.mean(), 3))
        print("defect by material:\n",
              df.groupby("material")["defect"].mean().round(3).to_string())
    return df

if not os.path.exists('weld_inspection.csv'):
    build_welds(); print('Generated dataset file.')
else:
    print('Found the provided dataset file.')


import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns
sns.set_theme(style='whitegrid')
df = pd.read_csv('weld_inspection.csv')
print('shape:', df.shape, '| defect rate:', round(df.defect.mean(), 3))
df.head(3)
# Out:
# Generated dataset file.
# shape: (2600, 10) | defect rate: 0.281
#    current_amp  voltage_v  travel_speed_mmps  wire_feed_mmps  heat_input_kjmm  \
# 0        247.7      23.37               7.78            7.57            0.744
# 1        227.3      22.98               8.90            5.96            0.587
# 2        230.6      24.46               8.15            7.76            0.692
#
#    gas_flow_lpm  joint_gap_mm  plate_thickness_mm   material  defect
# 0          16.0          0.79                 8.0     Carbon       0
# 1          16.5          0.66                12.0     Carbon       0
# 2          12.0          0.81                10.0  Stainless       0

# %% [markdown]
# ### Permutation Feature Importance for Tuned Gradient Boosting Model
#
# Permutation importance measures the increase in the prediction error of the model after permuting (shuffling) the values of a single feature. A feature is considered 'important' if shuffling its values significantly increases the model's error.

# %%
from sklearn.inspection import permutation_importance

# Calculate permutation importance on the test set
# Using the already defined best_gbr model, X_test, and y_test
result = permutation_importance(best_gbr, X_test, y_test, n_repeats=10, random_state=42, n_jobs=-1)

# Organize the results into a pandas Series for better readability and sorting
perm_importance_series = pd.Series(result.importances_mean, index=features).sort_values(ascending=True)

# Plot the permutation importances
fig, ax = plt.subplots(figsize=(8, 5))
perm_importance_series.plot(kind='barh', color='#3AAFA9', ax=ax)
ax.set_title('Permutation Feature Importance (Tuned Gradient Boosting Model)')
ax.set_xlabel('Mean Decrease in R2 Score (or other metric if changed)')
ax.set_ylabel('Features')
plt.tight_layout()
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 1A. CLASS BALANCE + A 2-D LOOK AT SEPARABILITY
# -----------------------------------------------------------
fig, ax = plt.subplots(1, 2, figsize=(11, 3.6))
df.defect.value_counts().plot(kind='bar', color=['#2D6A9F', '#C0392B'], ax=ax[0])
ax[0].set_xticklabels(['pass (0)', 'fail (1)'], rotation=0); ax[0].set_title('Class balance')
for v, c, lab in [(0, '#2D6A9F', 'pass'), (1, '#C0392B', 'fail')]:
    d = df[df.defect == v]
    ax[1].scatter(d.heat_input_kjmm, d.joint_gap_mm, s=8, alpha=0.35, color=c, label=lab)
ax[1].set_xlabel('heat_input_kjmm'); ax[1].set_ylabel('joint_gap_mm')
ax[1].set_title('Two drivers of defects'); ax[1].legend()
plt.tight_layout(); plt.show()
print('Defects cluster at extreme heat input and large joint gaps — but classes overlap (no perfect line).')
# Out:
# Defects cluster at extreme heat input and large joint gaps — but classes overlap (no perfect line).

# %%
# 1B. X / y + TRAIN-TEST SPLIT (stratified)
# -----------------------------------------------------------
from sklearn.model_selection import train_test_split
y = df['defect']
X = df.drop(columns='defect')
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, stratify=y, random_state=42)
print('train:', X_train.shape, '| test:', X_test.shape)
print('stratify keeps the defect rate equal in train & test:',
      round(y_train.mean(), 3), round(y_test.mean(), 3))
# Out:
# train: (1950, 9) | test: (650, 9)
# stratify keeps the defect rate equal in train & test: 0.281 0.282

# %%
pip install shap

# %% [markdown]
# ### Calculate SHAP values for the Tuned Gradient Boosting Model
#
# SHAP (SHapley Additive exPlanations) values help explain the output of any machine learning model by computing the contribution of each feature to the prediction for an individual instance. This allows for better understanding of feature importance and how features influence specific predictions.

# %%
import shap
import pandas as pd

# Assuming best_gbr is your tuned GradientBoostingRegressor model
# Assuming X_test is your test feature set (DataFrame is preferred for SHAP for feature names)

# SHAP needs feature names, so convert X_test to a DataFrame if it's not already
# The original 'features' list from the data loading step should be used.
# From context, `X` is already a DataFrame and `features` contains its column names.
# So, X_test should be converted back to a DataFrame with these feature names.

X_test_df = pd.DataFrame(X_test, columns=features)

# Create a SHAP TreeExplainer for tree-based models
explainer = shap.TreeExplainer(best_gbr)

# Calculate SHAP values for the test set
shap_values = explainer.shap_values(X_test_df)

# Visualize the SHAP values
shap.summary_plot(shap_values, X_test_df, plot_type="bar", show=False)
plt.title('SHAP Feature Importance (Bar Plot)')
plt.tight_layout()
plt.show()

shap.summary_plot(shap_values, X_test_df, show=False)
plt.title('SHAP Feature Importance (Summary Plot)')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_nanfunctions_impl.py:1424: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(

# %%
# 2A. PIPELINE (scale + one-hot) + LOGISTIC REGRESSION
# -----------------------------------------------------------
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
num = X.select_dtypes('number').columns.tolist()
cat = ['material']
pre = ColumnTransformer([('num', StandardScaler(), num),
                         ('cat', OneHotEncoder(drop='first'), cat)])
clf = Pipeline([('prep', pre), ('lr', LogisticRegression(max_iter=2000))]).fit(X_train, y_train)
proba = clf.predict_proba(X_test)[:, 1]      # P(defect)
print('first 5 predicted defect probabilities:', proba[:5].round(3))
print('logistic regression outputs a probability, not just a label.')
# Out:
# first 5 predicted defect probabilities: [0.189 0.429 0.322 0.647 0.181]
# logistic regression outputs a probability, not just a label.

# %%
from sklearn.metrics import roc_auc_score

# Calculate AUC score using predicted probabilities (proba) and true labels (y_test)
auc_score = roc_auc_score(y_test, proba)
print(f'Logistic Regression AUC Score: {auc_score:.3f}')
# Out:
# Logistic Regression AUC Score: 0.703

# %%
# 3A. CONFUSION MATRIX + CLASSIFICATION REPORT
# -----------------------------------------------------------
from sklearn.metrics import confusion_matrix, classification_report
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(4, 3.4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['pass', 'fail'], yticklabels=['pass', 'fail'], ax=ax)
ax.set_xlabel('predicted'); ax.set_ylabel('actual'); ax.set_title('Confusion matrix (threshold 0.5)')
plt.tight_layout(); plt.show()
print(classification_report(y_test, y_pred, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.752     0.927     0.830       467
#            1      0.541     0.219     0.311       183
#
#     accuracy                          0.728       650
#    macro avg      0.646     0.573     0.571       650
# weighted avg      0.692     0.728     0.684       650

# %%
# 🔹 4A. ROC CURVE ACROSS ALL THRESHOLDS
# -----------------------------------------------------------
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thr = roc_curve(y_test, proba)
auc = roc_auc_score(y_test, proba)
fig, ax = plt.subplots(figsize=(5, 4.2))
ax.plot(fpr, tpr, color='#3AAFA9', lw=2.5, label=f'logistic (AUC={auc:.3f})')
ax.plot([0, 1], [0, 1], ls='--', color='#888', label='random (0.5)')
ax.set_xlabel('false positive rate'); ax.set_ylabel('true positive rate')
ax.set_title('ROC curve'); ax.legend(); plt.tight_layout(); plt.show()
print(f'ROC-AUC: {auc:.3f}  (1.0 = perfect, 0.5 = random)')
# which ranks better? ...   (comment)
# Out:
# ROC-AUC: 0.703  (1.0 = perfect, 0.5 = random)

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.ensemble import RandomForestClassifier

# Define the preprocessing pipeline for the Random Forest Classifier
# This should be consistent with how X_train, X_test for the classification problem were prepared for Logistic Regression.
# We need to re-use the 'pre' ColumnTransformer defined in cell AEPdvVK13xwt.

# Assuming 'pre', 'num', 'cat', X_train, y_train, X_test, y_test are available from previous cells
# (from the weld inspection classification setup)

# Create a pipeline for Random Forest Classifier
rf_clf_pipeline = Pipeline([
    ('prep', pre),
    ('rf_clf', RandomForestClassifier(n_estimators=200, random_state=0))
])

# Fit the Random Forest Classifier pipeline
rf_clf_pipeline.fit(X_train, y_train)

# Get probabilities for the Random Forest Classifier model
# We need probabilities for the positive class (defect=1)
rf_proba = rf_clf_pipeline.predict_proba(X_test)[:, 1]

# Calculate ROC curve and AUC for Random Forest Classifier
rf_fpr, rf_tpr, rf_thr = roc_curve(y_test, rf_proba)
rf_auc = roc_auc_score(y_test, rf_proba)

print(f'Random Forest ROC-AUC: {rf_auc:.3f}')
# Out:
# Random Forest ROC-AUC: 0.659

# %%
fig, ax = plt.subplots(figsize=(7, 5.5))

# Plot Logistic Regression ROC curve (fpr, tpr, auc should be available from previous execution)
ax.plot(fpr, tpr, color='#3AAFA9', lw=2.5, label=f'Logistic Regression (AUC={auc:.3f})')

# Plot Random Forest ROC curve (rf_fpr, rf_tpr, rf_auc should now be available)
ax.plot(rf_fpr, rf_tpr, color='#2D6A9F', lw=2.5, label=f'Random Forest (AUC={rf_auc:.3f})')

# Plot random classifier line
ax.plot([0, 1], [0, 1], ls='--', color='#888', label='Random (0.5)')

ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curves: Logistic Regression vs. Random Forest')
ax.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# 🔹 5A. PRECISION & RECALL vs THRESHOLD
# -----------------------------------------------------------
from sklearn.metrics import precision_score, recall_score, f1_score
ts = np.linspace(0.1, 0.9, 17)
prec = [precision_score(y_test, (proba >= t).astype(int), zero_division=0) for t in ts]
rec = [recall_score(y_test, (proba >= t).astype(int)) for t in ts]
fig, ax = plt.subplots(figsize=(7, 4))
ax.plot(ts, prec, 'o-', label='precision', color='#2D6A9F')
ax.plot(ts, rec, 'o-', label='recall', color='#C0392B')
ax.axvline(0.5, ls='--', color='#888'); ax.set_xlabel('threshold'); ax.set_ylabel('score')
ax.set_title('Lower threshold -> higher recall, lower precision'); ax.legend()
plt.tight_layout(); plt.show()

# %%
for i, threshold in enumerate(ts):
    if rec[i] >= 0.85:
        print(f"For a recall >= 0.85 (achieved at {rec[i]:.3f}), the threshold is {threshold:.2f} and the precision is {prec[i]:.3f}.")
        break
else:
    print("No threshold found that achieves a recall >= 0.85.")
# Out:
# For a recall >= 0.85 (achieved at 0.984), the threshold is 0.10 and the precision is 0.291.

# %% [markdown]
# ### The Trade-off Between Precision and Recall
#
# The plot of precision and recall versus threshold, along with the previous calculation, clearly illustrates the inherent trade-off between these two metrics:
#
# *   **High Recall (e.g., Recall >= 0.85 at threshold 0.10, Precision = 0.291):** To achieve a high recall, meaning we correctly identify a large proportion of actual positive cases (defects in this context), we often need to lower the classification threshold. A lower threshold makes the model more sensitive, predicting more instances as positive. However, this typically comes at the cost of **lower precision**, as more false positives are also included. In our case, a high recall of 0.984 (meaning 98.4% of actual defects are caught) comes with a precision of only 0.291 (meaning only 29.1% of predicted defects are actually defects).
#
# *   **High Precision (Conversely):** To achieve high precision, meaning that when the model predicts a positive, it is very likely to be correct, we generally need to increase the classification threshold. A higher threshold makes the model more conservative, predicting fewer instances as positive. This leads to **lower recall**, as some actual positives might be missed (false negatives).
#
# **Choosing a Threshold:** The optimal threshold depends on the specific business problem and the costs associated with false positives versus false negatives. For example:
# *   In critical applications like medical diagnosis or defect detection (as in this case), **recall** might be prioritized to ensure that as many positive cases as possible are identified, even if it means a higher rate of false alarms.
# *   In applications where false positives are very costly (e.g., spam detection leading to lost important emails), **precision** might be prioritized.
#
# Our analysis showed that to capture a high percentage of defects (recall >= 0.85), a very low threshold (0.10) is required, resulting in relatively low precision. This suggests that while the model is good at identifying most defects, many of its positive predictions might be false alarms.

# %%
threshold_of_interest = 0.10

# Find the index corresponding to the threshold of 0.10
# Since ts might not contain 0.10 exactly due to floating point, we find the closest one or iterate.
# From the previous output, we know that for a recall >= 0.85, the threshold was 0.10.
# We can directly use the first elements of prec and rec arrays, as ts[0] is 0.10.

precision_at_0_10 = prec[0]
recall_at_0_10 = rec[0]

# Calculate F1-score
# Handle potential division by zero if both precision and recall are 0
if (precision_at_0_10 + recall_at_0_10) == 0:
    f1_at_0_10 = 0.0
else:
    f1_at_0_10 = 2 * (precision_at_0_10 * recall_at_0_10) / (precision_at_0_10 + recall_at_0_10)

print(f"At threshold {threshold_of_interest:.2f}:\n  Precision: {precision_at_0_10:.3f}\n  Recall: {recall_at_0_10:.3f}\n  F1-Score: {f1_at_0_10:.3f}")
# Out:
# At threshold 0.10:
#   Precision: 0.291
#   Recall: 0.984
#   F1-Score: 0.449

# %%
# 🔹 6A. exp(coefficient) = ODDS-RATIO PER +1 SD
# -----------------------------------------------------------
feat_names = clf.named_steps['prep'].get_feature_names_out()
coefs = clf.named_steps['lr'].coef_[0]
odds = pd.Series(np.exp(coefs), index=feat_names).sort_values(ascending=False)
print('Odds-ratio per +1 standardised unit (>1 raises defect odds, <1 lowers):')
print(odds.round(2).to_string())
# Out:
# Odds-ratio per +1 standardised unit (>1 raises defect odds, <1 lowers):
# num__joint_gap_mm          1.75
# num__plate_thickness_mm    1.25
# num__travel_speed_mmps     1.15
# num__current_amp           1.06
# num__voltage_v             0.96
# num__wire_feed_mmps        0.91
# num__gas_flow_lpm          0.83
# num__heat_input_kjmm       0.80
# cat__material_Stainless    0.56
# cat__material_Carbon       0.48

# %% [markdown]
# ### Interpreting Top/Bottom Odds-Ratios as Process Advice
#
# Based on the odds-ratios derived from the Logistic Regression model, we can provide process advice to either reduce or increase the likelihood of weld defects:
#
# **Top Odds-Ratios (Increase Defect Odds):**
#
# *   **`num__joint_gap_mm` (Odds-ratio: 1.75):** This is the feature with the highest odds-ratio. A one-standard-deviation increase in `joint_gap_mm` increases the odds of a defect by 75%. **Process Advice:** To significantly reduce the risk of defects, focus on maintaining a consistently small and precise `joint_gap_mm`. Any increase in this gap appears to strongly correlate with defects.
#
# *   **`num__plate_thickness_mm` (Odds-ratio: 1.25):** A one-standard-deviation increase in `plate_thickness_mm` increases the odds of a defect by 25%. **Process Advice:** While less impactful than joint gap, welding thicker plates tends to increase defect odds. Consider adjusting other parameters or techniques when working with thicker materials to compensate for this inherent increase in risk.
#
# *   **`num__travel_speed_mmps` (Odds-ratio: 1.15):** A one-standard-deviation increase in `travel_speed_mmps` increases the odds of a defect by 15%. **Process Advice:** Higher travel speeds are associated with slightly higher defect odds. Optimize travel speed to ensure proper fusion and penetration without introducing defects, possibly by moderating speed when other high-risk factors are present.
#
# **Bottom Odds-Ratios (Decrease Defect Odds):**
#
# *   **`cat__material_Carbon` (Odds-ratio: 0.48):** Compared to the baseline material (likely Aluminum, due to `drop='first'` in `OneHotEncoder`), welding with Carbon material reduces the odds of a defect by 52%. **Process Advice:** Welding Carbon steel appears to be less prone to defects. If material choice is flexible, opting for Carbon could be a way to reduce defect rates.
#
# *   **`cat__material_Stainless` (Odds-ratio: 0.56):** Similarly, Stainless Steel also reduces the odds of a defect by 44% compared to the baseline. **Process Advice:** Stainless steel also presents lower defect odds than the baseline material. This further reinforces that material properties play a significant role in weld quality.
#
# *   **`num__heat_input_kjmm` (Odds-ratio: 0.80):** A one-standard-deviation increase in `heat_input_kjmm` *decreases* the odds of a defect by 20%. **Process Advice:** This indicates that higher heat input (within a standard deviation) is associated with fewer defects. Ensuring adequate heat input is crucial. Too little heat input could lead to lack of fusion, while excessive heat input might cause other issues not captured here, but within the observed range, more heat is better.
#
# **Overall Takeaway:** Focusing on precise joint gap control is paramount for minimizing defects. Material choice and optimizing heat input are also strong levers for improving weld quality, while being mindful of travel speed for defect prevention.

# %%
fig, ax = plt.subplots(figsize=(8, 6))
odds.plot(kind='barh', color='#2D6A9F', ax=ax)
ax.set_title('Odds-Ratios of Features on Weld Defect Odds')
ax.set_xlabel('Odds-Ratio')
ax.set_ylabel('Feature')
plt.tight_layout()
plt.show()
